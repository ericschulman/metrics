# %%
import pandas
import math
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm

FNAME = '../Nerlove1963.dta'
df = pandas.read_stata(FNAME)
# Out:
# /home/erichschulman/anaconda2/lib/python2.7/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
print list(df)
# Out:
# ['cost', 'output', 'Plabor', 'Pfuel', 'Pcapital', 'lc', 'lq', 'lpl', 'lpf', 'lpc']

# %%
#part a, general model
y = df['lc']
X1 = df[['lq','lpl','lpf','lpc']]
X1 = sm.add_constant(X1)
model1 = sm.GLS(y,X1).fit()
model1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             GLS Regression Results
# ==============================================================================
# Dep. Variable:                     lc   R-squared:                       0.926
# Model:                            GLS   Adj. R-squared:                  0.924
# Method:                 Least Squares   F-statistic:                     437.7
# Date:                Sun, 18 Mar 2018   Prob (F-statistic):           4.82e-78
# Time:                        21:32:49   Log-Likelihood:                -67.542
# No. Observations:                 145   AIC:                             145.1
# Df Residuals:                     140   BIC:                             160.0
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -3.5265      1.774     -1.987      0.049      -7.035      -0.018
# lq             0.7204      0.017     41.244      0.000       0.686       0.755
# lpl            0.4363      0.291      1.499      0.136      -0.139       1.012
# lpf            0.4265      0.100      4.249      0.000       0.228       0.625
# lpc           -0.2199      0.339     -0.648      0.518      -0.891       0.451
# ==============================================================================
# Omnibus:                       51.403   Durbin-Watson:                   1.013
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              175.700
# Skew:                           1.303   Prob(JB):                     7.03e-39
# Kurtosis:                       7.721   Cond. No.                         506.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
#part c, impose the restriction b5 = 1- b3 - b4
#i.e. y -x5 = b0 + b1 x1 + b2 x2 + b3 (x3 -x5) + b4 (x4-x5)
X2 = pandas.DataFrame()
y2 = y.add(-1.0*X1['lpc'])
X2['lq'] = X1['lq']
X2['lpf'] = X1['lpf']
X2['lpl_lpc'] = X1['lpl'].add(-1.0*X1['lpc'])
X2['lpf_lpc'] = X1['lpf'].add(-1.0*X1['lpc'])
X2 = sm.add_constant(X1)
print X2
model2 = sm.GLS(y,X2).fit()
model2.summary()
# Out:
#            lq       lpf   lpl_lpc   lpf_lpc
# 0    0.693147  2.884801 -4.472322 -2.324685
# 1    1.098612  3.558201 -4.441216 -1.600854
# 2    1.386294  3.558201 -4.423824 -1.583462
# 3    1.386294  3.471967 -4.507671 -1.640021
# 4    1.609438  3.353407 -4.699622 -2.097632
# 5    2.197225  3.353407 -4.521584 -1.919593
# 6    2.397895  3.569533 -4.644779 -1.758343
# 7    2.564949  3.558201 -4.292796 -1.452434
# 8    2.564949  3.370738 -4.259523 -1.672687
# 9    3.091043  2.708050 -4.694118 -2.528392
# 10   3.218876  2.884801 -4.398634 -2.250998
# 11   3.218876  3.681351 -4.599200 -1.436643
# 12   3.555348  3.117950 -4.767965 -2.243342
# 13   3.663562  3.161247 -4.266957 -1.938620
# 14   3.761200  3.756538 -4.576183 -1.379260
# 15   4.143135  2.332144 -4.516090 -2.749260
# 16   4.219508  3.569533 -4.664011 -1.777575
# 17   4.394449  3.349904 -4.234043 -1.712691
# 18   4.430817  3.370738 -4.265954 -1.679118
# 19   4.290460  3.756538 -4.610868 -1.413946
# 20   4.595120  3.589059 -4.347341 -1.546739
# 21   4.615120  3.508556 -4.750678 -1.748940
# 22   4.779123  3.113515 -4.447541 -1.986351
# 23   4.787492  3.058707 -4.593806 -2.106079
# 24   4.804021  2.884801 -4.455793 -2.308156
# 25   4.867535  3.660994 -4.571648 -1.509490
# 26   4.927254  3.005683 -4.720481 -2.302585
# 27   5.003946  3.113515 -4.772625 -2.311435
# 28   5.278115  3.370738 -4.573421 -1.855008
# 29   5.283204  3.370738 -4.425584 -1.838748
# ..        ...       ...       ...       ...
# 115  8.097426  2.879198 -4.733252 -2.330288
# 116  8.105308  3.360375 -4.728230 -1.886649
# 117  8.159946  3.401197 -4.398634 -1.734601
# 118  8.171317  3.401197 -4.433320 -1.769287
# 119  8.241177  3.558201 -4.351065 -1.510703
# 120  8.253488  3.349904 -4.227694 -1.706342
# 121  8.297544  3.194583 -4.334716 -1.886821
# 122  8.346879  2.895912 -4.722227 -2.251582
# 123  8.367533  3.194583 -4.566518 -2.118623
# 124  8.410499  3.030134 -4.405044 -2.087860
# 125  8.468843  3.370738 -4.489098 -1.902261
# 126  8.571113  3.370738 -4.429079 -1.710666
# 127  8.572249  3.030134 -4.355955 -2.038771
# 128  8.642591  3.194583 -4.429462 -1.981567
# 129  8.644882  2.332144 -4.490932 -2.724102
# 130  8.668883  2.917771 -4.695899 -2.360344
# 131  8.699514  3.194583 -4.462798 -2.014903
# 132  8.719154  3.265759 -4.809965 -1.975987
# 133  8.721929  3.113515 -4.422849 -1.961658
# 134  8.880863  3.353407 -4.336180 -1.734190
# 135  8.972844  2.879198 -4.705549 -2.302585
# 136  9.038246  3.462606 -4.451738 -1.830699
# 137  9.064389  3.277145 -4.397531 -1.926862
# 138  9.081029  3.511545 -4.409777 -1.735479
# 139  9.157361  3.194583 -4.359258 -1.911362
# 140  9.205931  3.360375 -4.794413 -1.952831
# 141  9.348101  3.277145 -4.210804 -1.740135
# 142  9.375516  3.353407 -4.245796 -1.643806
# 143  9.572132  3.511545 -4.519339 -1.845041
# 144  9.724301  3.161247 -4.254687 -1.926350
#
# [145 rows x 4 columns]
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             GLS Regression Results
# ==============================================================================
# Dep. Variable:                     lc   R-squared:                       0.969
# Model:                            GLS   Adj. R-squared:                  0.968
# Method:                 Least Squares   F-statistic:                     1114.
# Date:                Sun, 18 Mar 2018   Prob (F-statistic):          1.45e-105
# Time:                        21:36:50   Log-Likelihood:                -69.559
# No. Observations:                 145   AIC:                             147.1
# Df Residuals:                     141   BIC:                             159.0
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# lq             0.7155      0.017     40.951      0.000       0.681       0.750
# lpf           -0.1687      0.238     -0.709      0.479      -0.639       0.302
# lpl_lpc        0.2785      0.283      0.984      0.327      -0.281       0.838
# lpf_lpc        0.6032      0.281      2.149      0.033       0.048       1.158
# ==============================================================================
# Omnibus:                       48.821   Durbin-Watson:                   1.067
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              151.045
# Skew:                           1.272   Prob(JB):                     1.59e-33
# Kurtosis:                       7.304   Cond. No.                         124.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
#part d
print model2.cov_HC0
model3 = sm.GLS(y2,X2,weights=model2.cov_HC0).fit()
model3.summary()
# Out:
# [[ 0.00098735 -0.00304468 -0.00186413  0.00291326]
#  [-0.00304468  0.04271715  0.04548306 -0.04657132]
#  [-0.00186413  0.04548306  0.0519873  -0.05262467]
#  [ 0.00291326 -0.04657132 -0.05262467  0.05597427]]
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             GLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.989
# Model:                            GLS   Adj. R-squared:                  0.989
# Method:                 Least Squares   F-statistic:                     3154.
# Date:                Sun, 18 Mar 2018   Prob (F-statistic):          8.24e-137
# Time:                        21:38:11   Log-Likelihood:                -69.559
# No. Observations:                 145   AIC:                             147.1
# Df Residuals:                     141   BIC:                             159.0
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# lq             0.7155      0.017     40.951      0.000       0.681       0.750
# lpf           -1.1687      0.238     -4.913      0.000      -1.639      -0.698
# lpl_lpc        0.2785      0.283      0.984      0.327      -0.281       0.838
# lpf_lpc        1.6032      0.281      5.711      0.000       1.048       2.158
# ==============================================================================
# Omnibus:                       48.821   Durbin-Watson:                   1.067
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              151.044
# Skew:                           1.272   Prob(JB):                     1.59e-33
# Kurtosis:                       7.304   Cond. No.                         124.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
#part e
model1.wald_test(([0,0,1,1,1],1))
# Out:
# <class 'statsmodels.stats.contrast.ContrastResults'>
# <F test: F=array([[ 0.57366045]]), p=0.450080906804, df_denom=140, df_num=1>

# %%
#part f
model4 = sm.GLS(y,X1,weights=model1.cov_HC0).fit()
model4.wald_test(([0,0,1,1,1],1))
# Out:
# <class 'statsmodels.stats.contrast.ContrastResults'>
# <F test: F=array([[ 0.57366045]]), p=0.450080906804, df_denom=140, df_num=1>
